# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key) > 10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")

MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}


class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
#
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/2024/10/16/from-software-engineer-to-ai-data-scientist-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
        ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/Qwen/Qwen2.5-Omni-7B',
#  '/deepseek-ai/DeepSeek-V3-0324',
#  '/manycore-research/SpatialLM-Llama-1B',
#  '/ds4sd/SmolDocling-256M-preview',
#  '/all-hands/openhands-lm-32b-v0.1',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/ByteDance/InfiniteYou-FLUX',
#  '/spaces/VAST-AI/TripoSG',
#  '/spaces/Stable-X/Hi3DGen',
#  '/spaces/jamesliu1217/EasyControl_Ghibli',
#  '/spaces',
#  '/datasets/nvidia/Llama-Nemotron-Post-Training-Dataset-v1',
#  '/datasets/a-m-team/AM-DeepSeek-R1-Distilled-1.4M',
#  '/datasets/glaiveai/reasoning-v1-20m',
#  '/datasets/FreedomIntelligence/medical-o1-reasoning-SFT',
#  '/datasets/PixelAI-Team/TalkBody4D',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord',
#  'https://www.zhihu.com/org/huggingface',
#  'https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/blog/chinese-language-blog/wechat.jpg']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'models page', 'url': 'https://huggingface.co/models'},
#   {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'},
#   {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://github.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# Qwen/Qwen2.5-Omni-7B
# Updated
# 3 days ago
# •
# 61.8k
# •
# 1.07k
# deepseek-ai/DeepSeek-V3-0324
# Updated
# 7 days ago
# •
# 101k
# •
# 2.23k
# manycore-research/SpatialLM-Llama-1B
# Updated
# 13 days ago
# •
# 13.2k
# •
# 870
# all-hands/openhands-lm-32b-v0.1
# Updated
# 2 days ago
# •
# 1.84k
# •
# 173
# ds4sd/SmolDocling-256M-preview
# Updated
# 11 days ago
# •
# 60.7k
# •
# 1.12k
# Browse 1M+ models
# Spaces
# Running
# 1.66k
# 1.66k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 724
# 724
# InfiniteYou-FLUX
# 📸
# Flexible Photo Recrafting While Preserving Your Identity
# Running
# on
# Zero
# 266
# 266
# EasyControl Ghibli
# 🦀
# New Ghibli EasyControl model is now released!!
# Running
# on
# Zero
# 248
# 248
# TripoSG
# 🔮
# Generate 3D models from images
# Running
# on
# Zero
# 242
# 242
# Hi3DGen
# 🏢
# High-fidelity 3D Geometry Generation from images
# Browse 400k+ applications
# Datasets
# nvidia/Llama-Nemotron-Post-Training-Dataset-v1
# Updated
# 15 days ago
# •
# 10.3k
# •
# 295
# glaiveai/reasoning-v1-20m
# Updated
# 14 days ago
# •
# 8.31k
# •
# 154
# a-m-team/AM-DeepSeek-R1-Distilled-1.4M
# Updated
# 4 days ago
# •
# 7.35k
# •
# 102
# FreedomIntelligence/medical-o1-reasoning-SFT
# Updated
# Feb 22
# •
# 24.4k
# •
# 599
# PixelAI-Team/TalkBody4D
# Updated
# 9 days ago
# •
# 78
# •
# 65
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 396 models
# •
# 2.99k followers
# AI at Meta
# Enterprise
# company
# •
# 2.07k models
# •
# 5.34k followers
# Amazon
# company
# •
# 10 models
# •
# 2.93k followers
# Google
# company
# •
# 974 models
# •
# 10.9k followers
# Intel
# company
# •
# 219 models
# •
# 2.39k followers
# Microsoft
# company
# •
# 365 models
# •
# 10.8k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 148 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 254 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 142,339
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 28,390
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,200
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,481
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,552
# Fast tokenizers optimized for research & production
# TRL
# 12,991
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,346
# State-of-the-art ML running directly in your browser
# smolagents
# 16,272
# Smol library to build great agents in Python
# PEFT
# 17,988
# Parameter-efficient finetuning for large language models
# Datasets
# 19,924
# Access & share datasets for any ML tasks
# Text Generation Inference
# 9,958
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,568
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# Qwen/Qwen2.5-Omni-7B
# Updated
# 3 days ago
# •
# 61.8k
# •
# 1.07k
# deepseek-ai/DeepSeek-V3-0324
# Updated
# 7 days ago
# •
# 101k
# •
# 2.23k
# manycore-research/SpatialLM-Llama-1B
# Updated
# 13 days ago
# •
# 13.2k
# •
# 870
# all-hands/openhands-lm-32b-v0.1
# Updated
# 2 days ago
# •
# 1.84k
# •
# 173
# ds4sd/SmolDocling-256M-preview
# Updated
# 11 days ago
# •
# 60.7k
# •
# 1.12k
# Browse 1M+ models
# Spaces
# Running
# 1.66k
# 1.66k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 724
# 724
# InfiniteYou-FLUX
# 📸
# Flexible Photo Recrafting While Preserving Your Identity
# Running
# on
# Zero
# 266
# 266
# EasyControl Ghibli
# 🦀
# New Ghibli EasyControl model is now released!!
# Running
# on
# Zero
# 248
# 248
# TripoSG
# 🔮
# Generate 3D models from images
# Running
# on
# Zero
# 242
# 242
# Hi3DGen
# 🏢
# High-fidelity 3D Geometry Generation from images
# Browse 400k+ applications
# Datasets
# nvidia/Llama-Nemotron-Post-Training-Dataset-v1
# Updated
# 15 days ago
# •
# 10.3k
# •
# 295
# glaiveai/reasoning-v1-20m
# Updated
# 14 days ago
# •
# 8.31k
# •
# 154
# a-m-team/AM-DeepSeek-R1-Distilled-1.4M
# Updated
# 4 days ago
# •
# 7.35k
# •
# 102
# FreedomIntelligence/medical-o1-reasoning-SFT
# Updated
# Feb 22
# •
# 24.4k
# •
# 599
# PixelAI-Team/TalkBody4D
# Updated
# 9 days ago
# •
# 78
# •
# 65
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 396 models
# •
# 2.99k followers
# AI at Meta
# Enterprise
# company
# •
# 2.07k models
# •
# 5.34k followers
# Amazon
# company
# •
# 10 models
# •
# 2.93k followers
# Google
# company
# •
# 974 models
# •
# 10.9k followers
# Intel
# company
# •
# 219 models
# •
# 2.39k followers
# Microsoft
# company
# •
# 365 models
# •
# 10.8k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 148 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 254 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 142,339
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 28,390
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,200
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,481
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,552
# Fast tokenizers optimized for research & production
# TRL
# 12,991
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,346
# State-of-the-art ML running directly in your browser
# smolagents
# 16,272
# Smol library to build great agents in Python
# PEFT
# 17,988
# Parameter-efficient finetuning for large language models
# Datasets
# 19,924
# Access & share datasets for any ML tasks
# Text Generation Inference
# 9,958
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,568
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# blog
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Accelerating LLM Inference with TGI on Intel Gaudi
# By
# baptistecolle
# March 28, 2025
# •
# 12
# Community Articles
# view all
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# 16 days ago
# •
# 117
# Open R1: Update #4
# By
# open-r1
# and 3 others
# •
# 7 days ago
# •
# 40
# Custom Vibe Coding Quest Part 2: 🚙 Fine-Tuning Gemma 3 for Code Reasoning
# By
# burtenshaw
# •
# 1 day ago
# •
# 17
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 504
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 152
# Training YOLOv8 with Synthetic Data from Falcon
# By
# DualityAI-RebekahBogdanoff
# •
# 1 day ago
# •
# 8
# Open R1: Update #3
# By
# open-r1
# and 9 others
# •
# 22 days ago
# •
# 279
# I Clicked “I Agree”, But What Am I Really Consenting To?
# By
# giadap
# •
# 8 days ago
# •
# 24
# Introducing EuroBERT: A High-Performance Multilingual Encoder Model
# By
# EuroBERT
# and 3 others
# •
# 24 days ago
# •
# 138
# Open-Source Handwritten Signature Detection Model
# By
# samuellimabraz
# •
# 19 days ago
# •
# 93
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 230
# Advancing European AI Sovereignty Through Racine.ai Flantier Open-Source Multimodal Models
# By
# paulml
# •
# 7 days ago
# •
# 6
# Ghibli AI: The Ultimate Guide to Studio Ghibli-Style AI Image Generation
# By
# LLMhacker
# •
# 4 days ago
# •
# 6
# Manus AI: The Best Autonomous AI Agent Redefining Automation and Productivity
# By
# LLMhacker
# •
# 28 days ago
# •
# 155
# Custom Vibe Coding Quest Part 1: The Quest Begins 🧙
# By
# burtenshaw
# •
# 8 days ago
# •
# 6
# Microsoft Playwright MCP: Tutorial for Beginners
# By
# lynn-mikami
# •
# 6 days ago
# •
# 5
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 90
# DeepSearch Using Visual RAG in Agentic Frameworks 🔎
# By
# paultltc
# and 1 other
# •
# 12 days ago
# •
# 29
# **TOP 11 Essential MCP Libraries**
# By
# LLMhacker
# •
# 15 days ago
# •
# 6
# Digest of models based on YandexGPT 5 Lite
# By
# WaveCut
# •
# 15 days ago
# •
# 29
# Training and Finetuning Reranker Models with Sentence Transformers v4
# By
# tomaarsen
# March 26, 2025
# •
# 88
# Introducing Gradio's new Dataframe!
# By
# hmb
# March 24, 2025
# •
# 21
# The New and Fresh analytics in Inference Endpoints
# By
# erikkaum
# March 21, 2025
# •
# 18
# Open R1: How to use OlympicCoder locally for coding?
# By
# burtenshaw
# March 20, 2025
# •
# 56
# AI Policy: 🤗 Response to the White House AI Action Plan RFI
# By
# yjernite
# March 19, 2025
# •
# 22
# NVIDIA's GTC 2025 Announcement for Physical AI Developers: New Open Models and Datasets
# By
# mingyuliutw
# March 18, 2025
# guest
# •
# 31
# Xet is on the Hub
# By
# jsulz
# March 18, 2025
# •
# 41
# Welcome Gemma 3: Google's all new multimodal, multilingual, long context open LLM
# By
# ariG23498
# March 12, 2025
# •
# 363
# LeRobot goes to driving school: World’s largest open-source self-driving dataset
# By
# sandhawalia
# March 11, 2025
# •
# 70
# LLM Inference on Edge: A Fun and Easy Guide to run LLMs via React Native on your Phone!
# By
# medmekk
# March 7, 2025
# •
# 48
# Hugging Face and JFrog partner to make AI Security more transparent
# By
# mcpotato
# March 4, 2025
# •
# 21
# A Deepdive into Aya Vision: Advancing the Frontier of Multilingual Multimodality
# By
# saurabhdash
# March 4, 2025
# guest
# •
# 71
# Trace & Evaluate your Agent with Arize Phoenix
# By
# m-ric
# February 28, 2025
# guest
# •
# 37
# HuggingFace, IISc partner to supercharge model building on India's diverse languages
# By
# prasantg
# February 27, 2025
# •
# 18
# Previous
# 1
# 2
# 3
# ...
# 40
# Next
# Community Articles
# Sort:
# 		Trending
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# 16 days ago
# •
# 117
# Open R1: Update #4
# By
# open-r1
# and 3 others
# •
# 7 days ago
# •
# 40
# Custom Vibe Coding Quest Part 2: 🚙 Fine-Tuning Gemma 3 for Code Reasoning
# By
# burtenshaw
# •
# 1 day ago
# •
# 17
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 504
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 152
# Training YOLOv8 with Synthetic Data from Falcon
# By
# DualityAI-RebekahBogdanoff
# •
# 1 day ago
# •
# 8
# Open R1: Update #3
# By
# open-r1
# and 9 others
# •
# 22 days ago
# •
# 279
# I Clicked “I Agree”, But What Am I Really Consenting To?
# By
# giadap
# •
# 8 days ago
# •
# 24
# Introducing EuroBERT: A High-Performance Multilingual Encoder Model
# By
# EuroBERT
# and 3 others
# •
# 24 days ago
# •
# 138
# Open-Source Handwritten Signature Detection Model
# By
# samuellimabraz
# •
# 19 days ago
# •
# 93
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 230
# Advancing European AI Sovereignty Through Racine.ai Flantier Open-Source Multimodal Models
# By
# paulml
# •
# 7 days ago
# •
# 6
# Ghibli AI: The Ultimate Guide to Studio Ghibli-Style AI Image Generation
# By
# LLMhacker
# •
# 4 days ago
# •
# 6
# Manus AI: The Best Autonomous AI Agent Redefining Automation and Productivity
# By
# LLMhacker
# •
# 28 days ago
# •
# 155
# Custom Vibe Coding Quest Part 1: The Quest Begins 🧙
# By
# burtenshaw
# •
# 8 days ago
# •
# 6
# Microsoft Playwright MCP: Tutorial for Beginners
# By
# lynn-mikami
# •
# 6 days ago
# •
# 5
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 90
# DeepSearch Using Visual RAG in Agentic Frameworks 🔎
# By
# paultltc
# and 1 other
# •
# 12 days ago
# •
# 29
# **TOP 11 Essential MCP Libraries**
# By
# LLMhacker
# •
# 15 days ago
# •
# 6
# Digest of models based on YandexGPT 5 Lite
# By
# WaveCut
# •
# 15 days ago
# •
# 29
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# company page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Reseting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 47k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 142k
# 28.5k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 28.4k
# 5.8k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 19.9k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 18k
# 1.8k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.6k
# 1.1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.8k
# 516
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 302 repositories
# trl
# Public
# Train transformer language models with reinforcement learning.
# huggingface/trl’s past year of commit activity
# Python
# 12,991
# Apache-2.0
# 1,761
# 340
# 82
# Updated
# Apr 3, 2025
# xet-core
# Public
# xet client tech, used in huggingface_hub
# huggingface/xet-core’s past year of commit activity
# Rust
# 69
# Apache-2.0
# 7
# 1
# 10
# Updated
# Apr 2, 2025
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# huggingface/transformers’s past year of commit activity
# Python
# 142,339
# Apache-2.0
# 28,502
# 1,045
# (2 issues need help)
# 673
# Updated
# Apr 2, 2025
# huggingface.js
# Public
# Utilities to use the Hugging Face Hub API
# huggingface/huggingface.js’s past year of commit activity
# TypeScript
# 1,570
# MIT
# 336
# 104
# (5 issues need help)
# 54
# Updated
# Apr 2, 2025
# nanotron
# Public
# Minimalistic large language model 3D-parallelism training
# huggingface/nanotron’s past year of commit activity
# Python
# 1,750
# Apache-2.0
# 169
# 60
# (20 issues need help)
# 47
# Updated
# Apr 2, 2025
# candle
# Public
# Minimalist ML framework for Rust
# huggingface/candle’s past year of commit activity
# Rust
# 16,928
# Apache-2.0
# 1,073
# 399
# (5 issues need help)
# 107
# Updated
# Apr 2, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 28,390
# Apache-2.0
# 5,810
# 467
# (12 issues need help)
# 186
# Updated
# Apr 2, 2025
# lerobot
# Public
# 🤗 LeRobot: Making AI for Robotics more accessible with end-to-end learning
# huggingface/lerobot’s past year of commit activity
# Python
# 11,526
# Apache-2.0
# 1,260
# 158
# 121
# Updated
# Apr 2, 2025
# optimum-executorch
# Public
# 🤗 Optimum ExecuTorch
# huggingface/optimum-executorch’s past year of commit activity
# Python
# 23
# Apache-2.0
# 5
# 11
# 3
# Updated
# Apr 2, 2025
# open-r1
# Public
# Fully open reproduction of DeepSeek-R1
# huggingface/open-r1’s past year of commit activity
# Python
# 23,652
# Apache-2.0
# 2,153
# 235
# 38
# Updated
# Apr 2, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# LinkedIn and 3rd parties use essential and non-essential cookies to provide, secure, analyze and improve our Services, and to show you relevant ads (including
# professional and job ads
# ) on and off LinkedIn. Learn more in our
# Cookie Policy
# .
# Select Accept to consent or Reject to decline non-essential cookies for this use. You can update your choices at any time in your
# settings
# .
# Accept
# Reject
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 517 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Bassem ASSEH
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# See all employees
# Updates
# Hugging Face
# reposted this
# Clem Delangue 🤗
# Clem Delangue 🤗 is an Influencer
# Co-founder & CEO at Hugging Face
# 1d
# Report this post
# Gradio just crossed 1,000,000 monthly developers in March!
#
# In my opinion, it's become one of the most important tools for democratization of AI that powered massively impactful apps like LMArena, Stable diffusion, Illusion Diffusion, InstantID, Kokoro, and thousands of new ones every day!
#
# Please join me in congratulating the
# Gradio
# team that joined
# Hugging Face
# almost 4 years ago, we're so happy to have them all!
#
# Now time for 10,000,000 users!
# 104
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 61,218 followers
# 18h
# Report this post
# 📊 1 MILLION DEVELOPERS ARE DEMOCRATIZING AI 📊
# Gradio has crossed 1M monthly active developers -- a milestone that represents more than just a number.
#
# 💯 It represents thousands of AI innovations being shared openly, tested quickly, and deployed globally.
#
# 🌉 From academic papers to production systems, Gradio has become the bridge connecting cutting-edge AI research with practical applications in:
# - Design
# - Finance
# - Education
# - Media
# - Learderboards
# - Enterprise solutions
#
# 🚩 This milestone validates our core belief: the most useful AI isn't the one with the most impressive benchmark numbers or best Ghibli converter, but the one that is the most accessible for builders and creators out there.
#
# 🤗 🧡 Thank you to the entire AI Community that made this possible. Here's to the next million!
# …more
# 86
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# 925,674 followers
# 9h
# Report this post
# 💣💥
#
# Inference Providers for organizations is UP
# Julien Chaumond
# CTO at Hugging Face
# 12h
# BOOOOM!
# We just launched Inference Providers for organizations 🔥
#
# (orgs need to be subscribed to
# Hugging Face
# Enterprise Hub given this feature requires billing)
#
# Some details ⤵️:
# - Each organization gets a pool of $2 of included usage per seat - shared among org members
# - Usage past those included credits is billed on top of the subscription (pay-as-you-go)
# - Organization admins can enable/disable usage of Inference Providers and set a spending limit (on top of included credits)
#
# Check the documentation on the Hub on how to bill your org for Inference Providers usage
#
# Feedback is welcome ❤️
# 22
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sergio Paniego Blanco
# ML Engineer @ Hugging Face 🤗 | AI PhD | Google Summer of Code '18-'24
# 1d
# Report this post
# 🆕New Unit in the Agents Course at
# Hugging Face
# .
#
# We just released the first Use Case on Agentic RAG—where we compare three frameworks side by side:
# 🤏 smolagents
# 🦙
# LlamaIndex
# 🦜 LangGraph (
# LangChain
# )
#
# 🔗 Course link:
# https://lnkd.in/dCnhGedq
# 609
# 9 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel Vila Suero
# Building data tools @ Hugging Face 🤗
# 2d
# Report this post
# What's the best open model for Chinese-to-English translation? I don't know! That's why I've just run a quick experiment 👇
#
#
# Today, I wanted to translate a very interesting Chinese dataset into English.
#
# Thanks to
# Hugging Face
# Inference Providers I compared V3, V3-0324, and Llama 70B using QwQ-32B as a translation quality evaluator.
#
# All without switching tools and providers and in under an hour!
#
# The result?
# V3 performs slightly better than V3-0324 (challenging my initial assumption), but both perform much better than Llama 70B.
#
# This is just a small dataset of 50 samples, but it gave me some instant insights about the task; I'll run some additional experiments on my final dataset.
#
# All prompts and the dataset are open source (see first comment)
# 36
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 61,218 followers
# 5d
# Edited
# Report this post
# Hi3DGen 🔥
#
# High-fidelity 3D geometry generation from a single image by leveraging normal maps as an intermediate representation
#
# Play with the fantastic app on
# Hugging Face
# now:
# https://lnkd.in/g99NpV_y
# …more
# 228
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Freddy Boulton
# Software Engineer @ 🤗
# 6d
# Report this post
# Generate lifelike audio in real-time without a GPU! 🚀
#
# Check out orpheus-cpp: a
# llama.cpp
# port of orpheus 3b text-to-speech model with built-in support for sync and async streaming.
#
# 𝚙𝚒𝚙 𝚒𝚗𝚜𝚝𝚊𝚕𝚕 𝚘𝚛𝚙𝚑𝚎𝚞𝚜-𝚌𝚙𝚙
# 𝚙𝚢𝚝𝚑𝚘𝚗 -𝚖 𝚘𝚛𝚙𝚑𝚎𝚞𝚜_𝚌𝚙𝚙
#
# Project code:
# https://lnkd.in/ekPpN9mc
# …more
# 437
# 13 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 61,218 followers
# 1w
# Report this post
# We just turned the humble dataframe into a superweapon⚡️
# dashboarding will never be the same!! 📊
#
# new Gradio Dataframe has:
# - multi-cell selection
# - column pinning
# - search + filtering
# - fullscreen mode
# - accessibility upgrades, and more
# …more
# 130
# 13 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗 | Google Developer Expert in Machine Learning, MSc Candidate in Data Science
# 1w
# Report this post
# is your vision LM in prod even safe? 👀
#
# ShieldGemma 2 is the first ever safety model for multimodal vision LMs in production by
# Google DeepMind
# , came with Gemma 3 🔥
#
# I saw confusion around how to use it, so I put together a notebook and a demo, find it in the comments 💬
# 410
# 11 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗 | Google Developer Expert in Machine Learning, MSc Candidate in Data Science
# 1w
# Report this post
# is your vision LM in prod even safe? 👀
#
# ShieldGemma 2 is the first ever safety model for multimodal vision LMs in production by
# Google DeepMind
# , came with Gemma 3 🔥
#
# I saw confusion around how to use it, so I put together a notebook and a demo, find it in the comments 💬
# 410
# 11 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Mistral AI
# Technology, Information and Internet
# Paris, France
# Perplexity
# Software Development
# San Francisco, California
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Cohere
# Software Development
# Toronto, Ontario
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000]  # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nQwen/Qwen2.5-Omni-7B\nUpdated\n3 days ago\n•\n61.8k\n•\n1.07k\ndeepseek-ai/DeepSeek-V3-0324\nUpdated\n7 days ago\n•\n101k\n•\n2.23k\nmanycore-research/SpatialLM-Llama-1B\nUpdated\n13 days ago\n•\n13.2k\n•\n870\nall-hands/openhands-lm-32b-v0.1\nUpdated\n2 days ago\n•\n1.84k\n•\n173\nds4sd/SmolDocling-256M-preview\nUpdated\n11 days ago\n•\n60.7k\n•\n1.12k\nBrowse 1M+ models\nSpaces\nRunning\n1.66k\n1.66k\nDeepSite\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\n725\n725\nInfiniteYou-FLUX\n📸\nFlexible Photo Recrafting While Preserving Your Identity\nRunning\non\nZero\n266\n266\nEasyControl Ghibli\n🦀\nNew Ghibli EasyControl model is now released!!\nRunning\non\nZero\n248\n248\nTripoSG\n🔮\nGenerate 3D models from images\nRunning\non\nZero\n242\n242\nHi3DGen\n🏢\nHigh-fidelity 3D Geometry Generation from images\nBrowse 400k+ applications\nDatasets\nnvidia/Llama-Nemotron-Post-Training-Dataset-v1\nUpdated\n15 days ago\n•\n10.3k\n•\n295\nglaiveai/reasoning-v1-20m\nUpdated\n14 days ago\n•\n8.31k\n•\n154\na-m-team/AM-DeepSeek-R1-Distilled-1.4M\nUpdated\n4 days ago\n•\n7.35k\n•\n102\nFreedomIntelligence/medical-o1-reasoning-SFT\nUpdated\nFeb 22\n•\n24.4k\n•\n599\nPixelAI-Team/TalkBody4D\nUpdated\n9 days ago\n•\n78\n•\n65\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n396 models\n•\n2.99k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.07k models\n•\n5.34k followers\nAmazon\ncompany\n•\n10 models\n•\n2.93k followers\nGoogle\ncompany\n•\n974 models\n•\n10.9k followers\nIntel\ncompany\n•\n219 models\n•\n2.39k followers\nMicrosoft\ncompany\n•\n365 models\n•\n10.8k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n148 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n254 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n142,339\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n28,390\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,200\nSafe way to store/distribute neural network weights\nHub Python Library\n2,481\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,552\nFast tokenizers optimized for research & production\nTRL\n12,991\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,346\nState-of-the-art ML running directly in your browser\nsmolagents\n16,272\nSmol library to build great agents in Python\nPEFT\n17,988\nParameter-efficient finetuning for l ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(
                company_name, url)}
        ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/about'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'contact page', 'url': 'https://huggingface.co/contact'}, {'type': 'forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face
# **_The AI community building the future._**
#
# At Hugging Face, we are dedicated to powering the machine learning community. Our platform serves as a collaborative hub where developers, researchers, and organizations can come together to share models, datasets, and applications that push the boundaries of AI.
#
# ---
#
# ## Our Offerings
#
# - **Models:** With over **1 million models** available, including state-of-the-art technologies in NLP, computer vision, and audio processing.
#
# - **Datasets:** A vast collection of **250,000+ datasets** ready for exploration and use in your AI projects.
#
# - **Spaces:** A space to deploy and showcase your applications, with **400,000+ applications** currently running.
#
# - **Enterprise Solutions:** Tailored for businesses, providing enterprise-grade security, access controls, and dedicated support to aid in the effective development and deployment of AI solutions.
#
# ---
#
# ## Company Culture
# At Hugging Face, we foster a culture of openness, collaboration, and innovation. As a dedicated AI community, we believe in building the future together, where every member plays a vital role in shaping AI for everyone.
#
# Our open-source philosophy encourages knowledge-sharing and engagement, empowering individuals to build their ML portfolios and contribute to the community.
#
# ---
#
# ## Our Customers
# More than **50,000 organizations**, including leading companies like Meta, Amazon, Google, and Microsoft, trust Hugging Face tools for their AI initiatives. Our community spans diverse sectors, from enterprise to non-profit, facilitating collaborations that enhance AI capabilities.
#
# ---
#
# ## Career Opportunities
# Hugging Face is always on the lookout for talented individuals who are passionate about AI and machine learning. We offer exciting career paths in various fields, providing the opportunity to work in a dynamic environment where your innovations can impact the future of technology.
#
# ### Join us:
# - Work alongside experts in the field.
# - Contribute directly to ground-breaking AI projects.
# - Engage in a diverse, inclusive workplace that values creativity and collaboration.
#
# ---
#
# ## Get Involved!
# Whether you're a developer, researcher, business leader, or just passionate about AI, we invite you to explore Hugging Face.
#
# - **Explore AI Apps**
# - **Browse Models and Datasets**
# - **Join Our Community**
# - **Sign Up Today!**
#
# For more information, visit us at **[Hugging Face](https://huggingface.co)**.
#
# Together, let’s build the future of AI!

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(
                company_name, url)}
        ],
        stream=True
    )

    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```", "").replace("markdown", "")
        update_display(Markdown(response),
                       display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ## About Us
# **Hugging Face** is more than just a technology company; we are a vibrant AI community focused on building the future of artificial intelligence. Our platform empowers collaboration among machine learning enthusiasts, researchers, and enterprises to create, share, and deploy cutting-edge AI models, datasets, and applications.
#
# ## Our Mission
# At Hugging Face, our mission is to democratize AI by providing tools and resources that facilitate innovation within the machine learning community. We believe in the power of open-source collaboration, which fuels our commitment to building the foundations of ML tooling.
#
# ## What We Offer
# - **Models**: Explore over **1 million AI models** across various tasks and domains, including text, image, video, and 3D applications.
# - **Datasets**: Access an extensive repository with more than **250,000 datasets** tailored for machine learning tasks.
# - **Spaces**: Utilize or contribute to over **400,000 applications** created by our community, enhancing your projects and accelerating your development process.
#
# ## Our Customers
# With more than **50,000 organizations** leveraging our platform, Hugging Face is trusted by industry leaders such as:
# - **AI at Meta**
# - **Amazon**
# - **Google**
# - **Microsoft**
# - **Intel**
#
# Our diverse clientele ranges from enterprises to non-profits, underscoring our versatile solutions that cater to various needs.
#
# ## Enterprise Solutions
# Join organizations that choose Hugging Face for enterprise-grade security and dedicated support. Starting at just **$20/user/month**, we provide:
# - Advanced access controls
# - Priority support
# - Private datasets viewer
# - Resource groups for data management
#
# ## Company Culture
# We foster a culture of collaboration, innovation, and inclusivity. Our team is composed of passionate individuals who believe in leveraging AI to make a positive impact. With a total team of **211** members and growing, we promote professional development and encourage contributions to open-source projects.
#
# ## Career Opportunities
# At Hugging Face, we are always on the lookout for talented individuals who resonate with our mission and values. If you want to be part of a forward-thinking team that is shaping the landscape of AI, check out our **careers page** to explore current job openings.
#
# ## Get Involved!
# Join us on our quest to build the future of AI. Whether you want to utilize our resources in your projects, contribute your models and data, or become a part of our team, Hugging Face welcomes you!
#
# ---
#
# For more information, visit our website at [Hugging Face](https://huggingface.co).
# Connect with us on [Twitter](https://twitter.com/huggingface) | [LinkedIn](https://linkedin.com/company/huggingface) | [Discord](https://discord.gg/huggingface)

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#
# </td>
# </tr>
#
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
